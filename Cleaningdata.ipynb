# %%
import pandas as pd

# %%
df = pd.read_csv("data/lotr_scripts.csv",encoding = "ISO-8859-1", dtype=str
)
df.head()
# Out:
#   Unnamed: 0     char                                             dialog  \
# 0          0   DEAGOL  Oh Smeagol Ive got one! , Ive got a fish Smeag...
# 1          1  SMEAGOL    Pull it in! Go on, go on, go on, pull it in! Â
# 2          2   DEAGOL                                           Arrghh!
# 3          3  SMEAGOL                                         Deagol! Â
# 4          4  SMEAGOL                                         Deagol! Â
#
#                      movie
# 0  The Return of the King
# 1  The Return of the King
# 2  The Return of the King
# 3  The Return of the King
# 4  The Return of the King

# %%
df.drop('Unnamed: 0',axis='columns', inplace=True)
df.head()
# Out:
#       char                                             dialog  \
# 0   DEAGOL  Oh Smeagol Ive got one! , Ive got a fish Smeag...
# 1  SMEAGOL    Pull it in! Go on, go on, go on, pull it in! Â
# 2   DEAGOL                                           Arrghh!
# 3  SMEAGOL                                         Deagol! Â
# 4  SMEAGOL                                         Deagol! Â
#
#                      movie
# 0  The Return of the King
# 1  The Return of the King
# 2  The Return of the King
# 3  The Return of the King
# 4  The Return of the King

# %%
df
# Out:
#          char                                             dialog  \
# 0      DEAGOL  Oh Smeagol Ive got one! , Ive got a fish Smeag...
# 1     SMEAGOL    Pull it in! Go on, go on, go on, pull it in! Â
# 2      DEAGOL                                           Arrghh!
# 3     SMEAGOL                                         Deagol! Â
# 4     SMEAGOL                                         Deagol! Â
# ...       ...                                                ...
# 2385   PIPPIN                                           Merry!Â
# 2386  ARAGORN                                            Merry!
# 2387    MERRY  He's always followed me everywhere I went sinc...
# 2388  ARAGORN  One thing I've learnt about Hobbits: They are ...
# 2389    MERRY                     Foolhardy maybe. He's a Took!
#
#                         movie
# 0     The Return of the King
# 1     The Return of the King
# 2     The Return of the King
# 3     The Return of the King
# 4     The Return of the King
# ...                       ...
# 2385  The Return of the King
# 2386  The Return of the King
# 2387  The Return of the King
# 2388  The Return of the King
# 2389  The Return of the King
#
# [2390 rows x 3 columns]

# %%
df.drop_duplicates()
# Out:
#          char                                             dialog  \
# 0      DEAGOL  Oh Smeagol Ive got one! , Ive got a fish Smeag...
# 1     SMEAGOL    Pull it in! Go on, go on, go on, pull it in! Â
# 2      DEAGOL                                           Arrghh!
# 3     SMEAGOL                                         Deagol! Â
# 6     SMEAGOL                    Give us that! Deagol my love Â
# ...       ...                                                ...
# 2385   PIPPIN                                           Merry!Â
# 2386  ARAGORN                                            Merry!
# 2387    MERRY  He's always followed me everywhere I went sinc...
# 2388  ARAGORN  One thing I've learnt about Hobbits: They are ...
# 2389    MERRY                     Foolhardy maybe. He's a Took!
#
#                         movie
# 0     The Return of the King
# 1     The Return of the King
# 2     The Return of the King
# 3     The Return of the King
# 6     The Return of the King
# ...                       ...
# 2385  The Return of the King
# 2386  The Return of the King
# 2387  The Return of the King
# 2388  The Return of the King
# 2389  The Return of the King
#
# [2368 rows x 3 columns]

# %%
df.to_json("data/scripts_lotr.json", orient="records")
